# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardmendoza92/datawarehouse-seguros/blob/main/notebooks/Aseguradoras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://raw.githubusercontent.com/eduardmendoza92/datawarehouse-seguros/refs/heads/main/data/aseguradoras.csv

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/eduardmendoza92/datawarehouse-seguros/refs/heads/main/data/aseguradoras.csv"

df = pd.read_csv(url)

df.head()
# Out:
#    id_aseguradora         nombre         pais rating_riesgo
# 0               1  Aseguradora 1   Costa Rica          Alto
# 1               2  Aseguradora 2  El Salvador          Bajo
# 2               3  Aseguradora 3  El Salvador           NaN
# 3               4  Aseguradora 4   Costa Rica         Medio
# 4               5  Aseguradora 5   ElSalvador             B

# %%
#Exploracion de datos
df.shape
df.columns
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_aseguradora  15 non-null     int64
#  1   nombre          15 non-null     object
#  2   pais            13 non-null     object
#  3   rating_riesgo   12 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 612.0+ bytes
# id_aseguradora    0
# nombre            0
# pais              2
# rating_riesgo     3
# dtype: int64

# %%
#Limpieza de datos
aseguradoras=df.copy()
print(aseguradoras['pais'].value_counts(dropna=False))
# Out:
# pais
# El Salvador    3
# ElSalvador     3
# Costa Rica     2
# NaN            2
# Panamá         2
# Honduras       2
# Guatemala      1
# Name: count, dtype: int64

# %%
aseguradoras['pais'] = aseguradoras['pais'].replace('ElSalvador', 'El Salvador')
print(aseguradoras['pais'].value_counts(dropna=False))
# Out:
# pais
# El Salvador    6
# Costa Rica     2
# NaN            2
# Panamá         2
# Honduras       2
# Guatemala      1
# Name: count, dtype: int64

# %%
asegudoras=df.copy()
print(aseguradoras['rating_riesgo'].value_counts(dropna=False))
# Out:
# rating_riesgo
# Alto     4
# Bajo     4
# NaN      3
# Medio    2
# B        1
# D        1
# Name: count, dtype: int64

# %%
#Separar datos válidos y rechazados
validos = aseguradoras[
    aseguradoras['pais'].notna() &
    aseguradoras['rating_riesgo'].notna()
].copy()

rechazados = asegudoras[asegudoras['pais'].isna() |
aseguradoras['rating_riesgo'].isna()
].copy()

# %%
#Motivo de rechazo
def motivo(row):
    motivos = []
    if pd.isna(row['pais']):
        motivos.append("pais_vacio")
    if pd.isna(row['rating_riesgo']):
        motivos.append("rating_riesgo_vacio")
    return ",".join(motivos)

rechazados["motivo_rechazo"] = rechazados.apply(motivo, axis=1)

# %%
validos.to_csv("aseguradoras_curated.csv", index=False)

rechazados.to_csv("aseguradoras_rejects.csv", index=False)
